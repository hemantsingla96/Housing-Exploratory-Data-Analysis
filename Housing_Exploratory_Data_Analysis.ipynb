# %% [markdown]
# <a href="https://colab.research.google.com/github/hemantsingla96/Housing-Exploratory-Data-Analysis/blob/main/Housing_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Introduction - Housing Exploratory Data Analysis
#
# Here we do Data Analysis of housing project.
#  In this project we will use Python libraries such as Matplotlib and seaborn to apply some data visualization technique to determine the distribution of the data. This dataset consists of the following features are as follows:

# %% [markdown]
# **FEATURES:**
#
# 1.**longitude**:A measure of distance a house is located horizontally that is from west to east,a higher value is further towards west.Statistically it comes under numerical data type, i.e.,Continuous data.
#
# 2.**latitude:**A measure of distance a house is located vertically that is towards north,a higher value is further towards north.Statistically it comes under numerical data type, i.e.,Continuous data
#
# 3.**housing_median_age:**It is Median age of a house.Statistically it is of quantitative datatype,i.e.,Continuous data.
#
# 4.**total_rooms:**Total number of rooms within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 5.**total_bedrooms**:Total number of bedrooms within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 6.**population:**Total number of people residing within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 7.**households:**Total number of households,a group of people residing within a homeunit.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 8.**median_income:**Median income of households within a block of houses.(measured in tens of thousands of US Dollars).It comes under continuous data.
#
# 9.**median_house_value**:Median house value for households within a block(measured in US Dollars).It comes under continuous data.
#
# 10.**Ocean_proximity:**Location of the house with respect to ocean.Statistically it is of categorical data i.e.,it is of nominal data type.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/housing+.csv") #we create the Dataframe of housing+ csv file
df.describe() # It gives the statistics of all numerical data
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
x = df['median_income'].mean() # we calculate the mean of "median_income" data using mean function
print(x)
# Out:
# 3.8706710029069766

# %%
df.hist(bins=50,figsize=(15,15)) #hist() function is used to show the distribution of data
plt.show()

# %% [markdown]
# **Explaination** - From the above plot,it is to be noted that the outliers are present for housing_median_age and for median_house_value.
#
# while total_rooms,total_bedrooms,population,households,median_income are of Right skewed.
#
# While latitude and logitude are of asymmetric,i.e.,highly skewed.

# %% [markdown]
# 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
plt.hist(df["housing_median_age"]) # hist() is used to get the distribution of "housing_median_age" data
plt.title("Distribution of housing_median_age") # title() is used to show the title of the graph
plt.xlabel("housing_median_age") # it gives the xlabel
plt.ylabel("Frequencies") # It gives the ylabel
plt.grid(True) # It creates the grid of the graph
plt.show()

# %% [markdown]
# From the above hist plot we can come to the analysis that it is distributed symmetrically.

# %% [markdown]
# 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
sns.scatterplot(x="median_income",y="median_house_value",data = df) #scatterplot gives the relationship between two numerical values
plt.show()

# %% [markdown]
# **Explaination** - From the above visualisation it is to be analysed that with an increase in the median_house_value there is also an increase in the median income.While,an outlier is present in median_house_value which is shown in the fig.Therefore,median_house_value is directly proportional to median income.

# %% [markdown]
# 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
df[df['total_bedrooms'].isnull()] #isnull() will give the boolean value true for null otherwise false
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
# ...

# %% [markdown]
# **Explaination** - In the above code,missing values are identified by using isnull()method.This missing values are identified in the column 'total_bedrooms'.

# %%
new_data=df.dropna(subset=["total_bedrooms"])#dropna() method allows the user to drop Rows/Columns with Null values.
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# **Explaination** - In the above code the missing values are dropped from the column named'total_bedrooms'by using dropna() method.

# %% [markdown]
# 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
x = df['total_bedrooms'].mean() # First We will find the mean of "total_bedrooms" data
df.fillna(x,inplace = True) # Using Fillna function fill all the missing value by mean of "total_bedrooms" data
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
def med(data):  #created a user defined function to calculate median
  data.sort_values()    # sort the data in ascending order
  N = len(data)
  if N%2 ==1:
    return data[N//2]
  else:
    a = data[N//2-1]
    b = data[N//2]
    return (a+b)/2


x = med(df["latitude"])
print(x)
# Out:
# 33.845

# %% [markdown]
# 7. Plot latitude versus longitude and explain your observations.

# %%
sns.scatterplot(x="longitude",y="latitude",data = df) # scatterplot shows the relationship between longitue and latitude

plt.show()

# %% [markdown]
# **Explaination -** From the above plot,it is to be noted that with an decrease in longitude,latitude is increased.From this point of view,it is to be known that latitude and longitude are not dependent on each other.From this we can say that longitude is inversely proportional to latitude.

# %% [markdown]
# 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
df1 = df[df['ocean_proximity']=='NEAR OCEAN'] # we create the new dataset df1 where ocean proximity coln having "near ocean" value only.
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# 9. Find the mean and median of the median income for the data set created in question 8.

# %%
a = df1["median_income"].mean() # Here we calculate the mean of "median_income" of new dataset df1
print(a)
# Out:
# 4.0057848006019565

# %%
b = df1["median_income"].median() # Here we calculate the median of "median_income" of new dataset df1
print(b)
# Out:
# 3.64705

# %% [markdown]
# 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
#Here we use loc function to create new coln based on the given condition

df.loc[df["total_bedrooms"]<=10,"total_bedroom_size"] = 'Small'
df.loc[(df["total_bedrooms"]>=11) & (df["total_bedrooms"]<1000) ,"total_bedroom_size"] = 'Medium'
df.loc[df["total_bedrooms"]>1000,"total_bedroom_size"] = 'Large'

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# In the above data set a new column named total_bedroom_size had been added.Where the total_bedroom_size had been compared to the total_bedrooms while mentioning about the sizes of the total_bedroom_size,where:
#
# If the total_bedroom_size <=10 it is indicated as "small" If the total_bedroom_size >=11 or <=1000 it is indicated as "medium" If the total_bedroom_size >1000 it is indicated as "large"
